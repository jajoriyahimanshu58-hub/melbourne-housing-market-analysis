# %%
import pandas as pd

# %%
df = pd.read_csv("C:/Users/Himanshu/Downloads/MELBOURNE_HOUSE_PRICES_LESS.csv (1)/MELBOURNE_HOUSE_PRICES_LESS.csv")
df
# Out:
#                  Suburb           Address  Rooms Type    Price Method  \
# 0            Abbotsford     49 Lithgow St      3    h  1490000      S
# 1            Abbotsford     59A Turner St      3    h  1220000      S
# 2            Abbotsford     119B Yarra St      3    h  1420000      S
# 3            Aberfeldie        68 Vida St      3    h  1515000      S
# 4          Airport West  92 Clydesdale Rd      2    h   670000      S
# ...                 ...               ...    ...  ...      ...    ...
# 63018     Roxburgh Park         3 Carr Pl      3    h   566000      S
# 63019     Roxburgh Park       9 Parker Ct      3    h   500000      S
# 63020     Roxburgh Park    5 Parkinson Wy      3    h   545000      S
# 63021        Thomastown    3/1 Travers St      3    u        0     PI
# 63022  Williams Landing       1 Diadem Wy      4    h        0     SP
#
#         SellerG        Date  Postcode             Regionname  Propertycount  \
# ...

# %%
df.describe()
# Out:
#               Rooms         Price      Postcode  Propertycount      Distance
# count  63023.000000  6.302300e+04  63023.000000   63023.000000  63023.000000
# mean       3.110595  7.668820e+05   3125.673897    7617.728131     12.684829
# std        0.957551  6.692234e+05    125.626877    4424.423167      7.592015
# min        1.000000  0.000000e+00   3000.000000      39.000000      0.000000
# 25%        3.000000  3.630000e+05   3056.000000    4380.000000      7.000000
# 50%        3.000000  6.975000e+05   3107.000000    6795.000000     11.400000
# 75%        4.000000  1.065000e+06   3163.000000   10412.000000     16.700000
# max       31.000000  1.120000e+07   3980.000000   21650.000000     64.100000

# %%
df.shape
# Out:
# (63023, 13)

# %%
df.isnull().sum()
#df.dropna(inplace=True)
# Out:
# Suburb           0
# Address          0
# Rooms            0
# Type             0
# Price            0
# Method           0
# SellerG          0
# Date             0
# Postcode         0
# Regionname       0
# Propertycount    0
# Distance         0
# CouncilArea      0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df["Price"].fillna(df["Price"].median(), inplace=True)
# Out:
# C:\Users\Himanshu\AppData\Local\Temp\ipykernel_35852\4076299458.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Price"].fillna(df["Price"].median(), inplace=True)

# %%
df.isnull().sum()
# Out:
# Suburb           0
# Address          0
# Rooms            0
# Type             0
# Price            0
# Method           0
# SellerG          0
# Date             0
# Postcode         0
# Regionname       0
# Propertycount    0
# Distance         0
# CouncilArea      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(2)

# %%
df.drop_duplicates(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 63021 entries, 0 to 63022
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         63021 non-null  object
#  1   Address        63021 non-null  object
#  2   Rooms          63021 non-null  int64
#  3   Type           63021 non-null  object
#  4   Price          63021 non-null  int64
#  5   Method         63021 non-null  object
#  6   SellerG        63021 non-null  object
#  7   Date           63021 non-null  object
#  8   Postcode       63021 non-null  int64
#  9   Regionname     63021 non-null  object
#  10  Propertycount  63021 non-null  int64
#  11  Distance       63021 non-null  float64
#  12  CouncilArea    63021 non-null  object
# dtypes: float64(1), int64(4), object(8)
# memory usage: 6.7+ MB

# %%
df = df[["Suburb","Rooms","Type","Price","Date","Regionname"]]
df
# Out:
#                  Suburb  Rooms Type    Price        Date  \
# 0            Abbotsford      3    h  1490000  01-04-2017
# 1            Abbotsford      3    h  1220000  01-04-2017
# 2            Abbotsford      3    h  1420000  01-04-2017
# 3            Aberfeldie      3    h  1515000  01-04-2017
# 4          Airport West      2    h   670000  01-04-2017
# ...                 ...    ...  ...      ...         ...
# 63018     Roxburgh Park      3    h   566000  31-03-2018
# 63019     Roxburgh Park      3    h   500000  31-03-2018
# 63020     Roxburgh Park      3    h   545000  31-03-2018
# 63021        Thomastown      3    u        0  31-03-2018
# 63022  Williams Landing      4    h        0  31-03-2018
#
#                   Regionname
# 0      Northern Metropolitan
# 1      Northern Metropolitan
# 2      Northern Metropolitan
# 3       Western Metropolitan
# 4       Western Metropolitan
# ...                      ...
# 63018  Northern Metropolitan
# 63019  Northern Metropolitan
# ...

# %%
import matplotlib.pyplot as plt 
plt.boxplot(df["Price"])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# 1. House Type Distribution

# %%
df["Type"].value_counts().plot(kind="bar")
plt.title("Property Type Distribution")
plt.show()

# %% [markdown]
# 2. Price Distribution (Histogram)

# %%
plt.figure(figsize=(8,5))
plt.hist(df["Price"], bins=30)
plt.title("Price Distribution")
plt.xlabel("Price")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# 3. Average Price by Region

# %%
avg_price = df.groupby("Regionname")["Price"].mean().sort_values()

avg_price.plot(kind="barh", figsize=(10,6))
plt.title("Average Price by Region")
plt.show()

# %% [markdown]
# 4. Rooms vs Price

# %%
plt.figure(figsize=(8,5))
plt.scatter(df["Rooms"], df["Price"])
plt.xlabel("Rooms")
plt.ylabel("Price")
plt.title("Rooms vs Price")
plt.show()

# %% [markdown]
# 5. Correlation Heatmap

# %%
df = df[["Suburb","Rooms","Type","Price","Regionname"]]

# %%
print(df.columns)
# Out:
# Index(['Suburb', 'Rooms', 'Type', 'Price', 'Regionname'], dtype='object')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.heatmap(
    df[["Price", "Rooms"]].corr(),
    annot=True,
    cmap="coolwarm"
)
plt.show()

# %%
df.to_csv("cleaned_MELBOURNE_housing.csv", index=False)
